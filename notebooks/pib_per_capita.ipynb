# %%
#Importing packages.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_profiling as pdp
plt.style.use('seaborn')

# %%
#Loading data.
xls = pd.ExcelFile('../data/gdpspain.xls')
pib = pd.read_excel(xls, 'Data')
pib
# Out:
#   Country Name         1995          1996          1997          1998  \
# 0       España  11594.68886  12263.845953  12963.101514  13822.588178
#
#           1999          2000          2001          2002          2003  ...  \
# 0  14750.41087  15969.561523  17159.998288  18091.330285  19016.610195  ...
#
#            2011          2012          2013          2014         2015  \
# 0  22757.843862  22044.722116  21886.465361  22206.076038  23201.50496
#
#            2016          2017          2018          2019          2020
# 0  23961.761345  24936.387762  25732.880257  26409.484664  23688.719742
#
# [1 rows x 27 columns]

# %%
pib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  1 non-null      object
#  1   1995          1 non-null      float64
#  2   1996          1 non-null      float64
#  3   1997          1 non-null      float64
#  4   1998          1 non-null      float64
#  5   1999          1 non-null      float64
#  6   2000          1 non-null      float64
#  7   2001          1 non-null      float64
#  8   2002          1 non-null      float64
#  9   2003          1 non-null      float64
#  10  2004          1 non-null      float64
#  11  2005          1 non-null      float64
#  12  2006          1 non-null      float64
#  13  2007          1 non-null      float64
#  14  2008          1 non-null      float64
#  15  2009          1 non-null      float64
#  16  2010          1 non-null      float64
# ...

# %%
del(pib["Country Name"])
pib = pib.transpose()
pib
# Out:
#                  0
# 1995  11594.688860
# 1996  12263.845953
# 1997  12963.101514
# 1998  13822.588178
# 1999  14750.410870
# 2000  15969.561523
# 2001  17159.998288
# 2002  18091.330285
# 2003  19016.610195
# 2004  20023.277164
# 2005  21243.756608
# 2006  22609.991383
# 2007  23781.008797
# 2008  24144.545430
# 2009  23064.172842
# 2010  23030.924538
# 2011  22757.843862
# 2012  22044.722116
# 2013  21886.465361
# 2014  22206.076038
# 2015  23201.504960
# 2016  23961.761345
# 2017  24936.387762
# 2018  25732.880257
# 2019  26409.484664
# 2020  23688.719742

# %%
pib.describe()
# Out:
#                   0
# count     26.000000
# mean   20398.294559
# std     4413.693030
# min    11594.688860
# 25%    17392.831288
# 50%    22125.399077
# 75%    23566.916046
# max    26409.484664

# %%
fig = plt.figure(figsize=(40,20))

ax1 = plt.plot(pib, marker='', markerfacecolor='blue', markersize=1, color='goldenrod', 
          linewidth=10)

ax1 = plt.xlabel("Año", fontsize=50, weight="bold")
x = plt.xticks(fontsize=50, rotation=50, weight="bold")
ax1 = plt.ylabel("Euros", fontsize=50, weight="bold")
y = plt.yticks(fontsize=50, weight="bold")

ax1 = plt.legend(['Renta per Capita en España'],prop={"size":70, 'weight':'bold'}, loc="upper left")

plt.vlines(2020, 10000, 27000, linestyles='dashed', colors='black', linewidth=6)

plt.grid(True)
plt.show()
