# %%
#Importing packages.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_profiling as pdp
plt.style.use('seaborn')

# %%
#Loading data.
xls = pd.ExcelFile('../data/casasPVO.xls')
proteccion = pd.read_excel(xls, 'Hoja1')
proteccion
# Out:
#        Unnamed: 0   1991   1992   1993   1994   1995   1996   1997   1998  \
# 0  TOTAL NACIONAL  41601  39971  44981  60351  69880  78826  81321  71285
#
#     1999  ...   2011   2012   2013  2014  2015  2016  2017  2018  2019  2020
# 0  56888  ...  48728  44174  13513  6182  2651  3332  2050   184   376   515
#
# [1 rows x 31 columns]

# %%
proteccion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 31 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1 non-null      object
#  1   1991        1 non-null      int64
#  2   1992        1 non-null      int64
#  3   1993        1 non-null      int64
#  4   1994        1 non-null      int64
#  5   1995        1 non-null      int64
#  6   1996        1 non-null      int64
#  7   1997        1 non-null      int64
#  8   1998        1 non-null      int64
#  9   1999        1 non-null      int64
#  10  2000        1 non-null      int64
#  11  2001        1 non-null      int64
#  12  2002        1 non-null      int64
#  13  2003        1 non-null      int64
#  14  2004        1 non-null      int64
#  15  2005        1 non-null      int64
#  16  2006        1 non-null      int64
#  17  2007        1 non-null      int64
#  18  2008        1 non-null      int64
# ...

# %%
del(proteccion["Unnamed: 0"])
proteccion = proteccion.transpose()
proteccion
# Out:
#           0
# 1991  41601
# 1992  39971
# 1993  44981
# 1994  60351
# 1995  69880
# 1996  78826
# 1997  81321
# 1998  71285
# 1999  56888
# 2000  52270
# 2001  48944
# 2002  34040
# 2003  40002
# 2004  53101
# 2005  58267
# 2006  55579
# 2007  57573
# 2008  60207
# 2009  56960
# 2010  49402
# 2011  48728
# 2012  44174
# 2013  13513
# 2014   6182
# 2015   2651
# 2016   3332
# 2017   2050
# 2018    184
# 2019    376
# 2020    515

# %%
proteccion.describe()
# Out:
#                   0
# count     30.000000
# mean   41105.133333
# std    25404.839199
# min      184.000000
# 25%    18644.750000
# 50%    48836.000000
# 75%    57419.750000
# max    81321.000000

# %%
fig = plt.figure(figsize=(40,20))

ax1 = plt.plot(proteccion, marker='', markerfacecolor='blue', markersize=1, color='mediumslateblue', 
          linewidth=10)

ax1 = plt.xlabel("Año", fontsize=50, weight="bold")
x = plt.xticks(fontsize=50, rotation=50, weight="bold")
ax1 = plt.ylabel("Número de viviendas", fontsize=50, weight="bold")
y = plt.yticks(fontsize=50, weight="bold")

ax1 = plt.legend(['Nuevas viviendas de protección oficial en España'],prop={"size":60, 'weight':'bold'}, loc="lower left")

plt.vlines(2020, 180, 82000, linestyles='dashed', colors='black', linewidth=6)

plt.grid(True)
plt.show()
